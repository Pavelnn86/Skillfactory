# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import itertools as it

# %%
data = pd.read_csv('/Users/pavelfilchenkov/Desktop/movie_bd_v5.csv')
data.sample(5)
# Out:
#         imdb_id    budget    revenue                 original_title  \
# 557   tt0221218  30000000   23619609                The Glass House
# 1415  tt0388980  25000000   15431177  The Greatest Game Ever Played
# 1407  tt0379725   7000000   49084830                         Capote
# 246   tt1136608  30000000  210819611                     District 9
# 1128  tt0348836  40000000  141591324                        Gothika
#
#                                                    cast           director  \
# 557   Leelee Sobieski|Diane Lane|Stellan SkarsgÃ¥rd|...    Daniel Sackheim
# 1415  Shia LaBeouf|Stephen Dillane|Josh Flitter|Pete...        Bill Paxton
# 1407  Philip Seymour Hoffman|Allie Mickelson|Craig A...     Bennett Miller
# 246   Sharlto Copley|Jason Cope|Nathalie Boltt|Sylva...     Neill Blomkamp
# 1128  Halle Berry|Robert Downey Jr.|Charles S. Dutto...  Mathieu Kassovitz
#
#                                                 tagline  \
# ...

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...

# %%
data.head(10)
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
# 5  tt1663202  135000000   532950503                  The Revenant
# 6  tt1340138  155000000   440603537            Terminator Genisys
# 7  tt3659388  108000000   595380321                   The Martian
# 8  tt2293640   74000000  1156730962                       Minions
# 9  tt2096673  175000000   853708609                    Inside Out
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# ...

# %%
data.dtypes
# Out:
# imdb_id                  object
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# director                 object
# tagline                  object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_average            float64
# release_year              int64
# dtype: object

# %%
data2 = data.copy()
data2['cast'] = data2.cast.str.split('|')
data2['director'] = data2.director.str.split('|')
data2['genres'] = data2.genres.str.split('|')
data2['production_companies'] = data2.production_companies.str.split('|')
data2['release_date'] = pd.to_datetime(data2['release_date'])
data2
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                             Insurgent
# 3     tt2488496  200000000  2068178225          Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                             Furious 7
# ...         ...        ...         ...                                   ...
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1885  tt0192255   22000000    13555988                    The Little Vampire
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %%
data2.dtypes
# Out:
# imdb_id                         object
# budget                           int64
# revenue                          int64
# original_title                  object
# cast                            object
# director                        object
# tagline                         object
# overview                        object
# runtime                          int64
# genres                          object
# production_companies            object
# release_date            datetime64[ns]
# vote_average                   float64
# release_year                     int64
# dtype: object

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
answers['1'] = '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)'

# %%
# тут пишем ваш код для решения данного вопроса:
d1 = data[data['budget'] == data['budget'].max()]
d1
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year
# 723           6.3          2011

# %% [markdown]
# ВАРИАНТ 2

# %%
data.loc[data.budget == data.budget.max()]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year
# 723           6.3          2011

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
answers['2'] = '2. Gods and Generals  (tt0279111)'

# %%
# Вариант 1
d2 = data[data['runtime'] == data['runtime'].max()]
d2
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year
# 1157           5.8          2003

# %% [markdown]
# ВАРИАНТ 2

# %%
# Вариант 2
data.loc[data.runtime == data.runtime.max()]
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year
# 1157           5.8          2003

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = '3. Winnie the Pooh (tt1449283)'

# %%
data.loc[data.runtime == data.runtime.min()]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year
# 768    4/13/2011           6.8          2011

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '2. 110'

# %%
data.runtime.mean()
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '1. 107'

# %%
data.runtime.median()
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?

# %% [markdown]
# **Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)**

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале

# %%
answers['6'] = '5. Avatar (tt0499549)'

# %%
data2['profit'] = data2['revenue'] - data2['budget']
data2
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                             Insurgent
# 3     tt2488496  200000000  2068178225          Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                             Furious 7
# ...         ...        ...         ...                                   ...
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1885  tt0192255   22000000    13555988                    The Little Vampire
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %%
data2.loc[data2.profit == data2.profit.max()]
# Out:
#        imdb_id     budget     revenue original_title  \
# 239  tt0499549  237000000  2781505847         Avatar
#
#                                                   cast         director  \
# 239  [Sam Worthington, Zoe Saldana, Sigourney Weave...  [James Cameron]
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                             genres  \
# 239  [Action, Adventure, Fantasy, Science Fiction]
#
#                                   production_companies release_date  \
# 239  [Ingenious Film Partners, Twentieth Century Fo...   2009-12-10
#
#      vote_average  release_year      profit
# 239           7.1          2009  2544505847

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = '5. The Lone Ranger  (tt1210819)'

# %%
data2.loc[data2.profit == data2.profit.min()]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast          director  \
# 1245  [Johnny Depp, Armie Hammer, William Fichtner, ...  [Gore Verbinski]
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                             genres  \
# 1245  [Action, Adventure, Western]
#
#                                    production_companies release_date  \
# 1245  [Walt Disney Pictures, Jerry Bruckheimer Films...   2013-07-03
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = '1. 1478 '

# %%
data.loc[data.revenue > data.budget]
# Out:
#         imdb_id     budget     revenue                original_title  \
# 0     tt0369610  150000000  1513528810                Jurassic World
# 1     tt1392190  150000000   378436354            Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                     Insurgent
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                     Furious 7
# ...         ...        ...         ...                           ...
# 1871  tt0171433   30000000    37036004             Keeping the Faith
# 1875  tt0219854   65000000    69700000                       The Kid
# 1877  tt0199725   20000000    27728118             Love & Basketball
# 1883  tt0122459   24000000    36609995                  Return to Me
# 1884  tt0120903   75000000   157299717                         X-Men
#
#                                                    cast  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# ...

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9'] = '4. The Dark Knight (tt0468569)'

# %%
d3 = data.loc[data.release_year == 2008]
d3
# Out:
#        imdb_id     budget     revenue  \
# 599  tt0468569  185000000  1001921825
# 600  tt0910970  180000000   521311860
# 601  tt0371746  140000000   585174222
# 602  tt0936501   25000000   226830568
# 603  tt0367882  185000000   786636033
# ..         ...        ...         ...
# 715  tt0858479    7000000    10569964
# 716  tt0410377   37000000   100076342
# 717  tt0465502   25000000    30000000
# 718  tt0455538   27000000    17286299
# 719  tt0494652   35000000    43650785
#
#                                         original_title  \
# 599                                    The Dark Knight
# 600                                            WALLÂ·E
# 601                                           Iron Man
# 602                                              Taken
# 603  Indiana Jones and the Kingdom of the Crystal S...
# ..                                                 ...
# 715                                       Smart People
# ...

# %%
d3.loc[d3.revenue == d3.revenue.max()]
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year
# 599           8.1          2008

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10'] = '5. The Lone Ranger (tt1210819)'

# %%
d4 = data2.loc[(data2.release_year > 2011) & (data2.release_year < 2015)]
d4
# Out:
#         imdb_id     budget    revenue                         original_title  \
# 118   tt0816692  165000000  621752480                           Interstellar
# 119   tt2015381  170000000  773312399                Guardians of the Galaxy
# 120   tt1843866  170000000  714766572    Captain America: The Winter Soldier
# 121   tt2911666   20000000   78739897                              John Wick
# 122   tt1951265  125000000  752100229  The Hunger Games: Mockingjay - Part 1
# ...         ...        ...        ...                                    ...
# 1307  tt2431286   12000000  100129872                              Philomena
# 1308  tt1758595   15000000   21766271                                  Diana
# 1309  tt2167202   18000000   10501938                                Getaway
# 1310  tt2234155   58000000   44000000                         The Internship
# 1311  tt1966566   30000000   68129518                   Ð¡Ñ‚Ð°Ð»Ð¸Ð½Ð³Ñ€Ð°Ð´
#
# ...

# %%
d4.loc[d4.profit == d4.profit.min()]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast          director  \
# 1245  [Johnny Depp, Armie Hammer, William Fichtner, ...  [Gore Verbinski]
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                             genres  \
# 1245  [Action, Adventure, Western]
#
#                                    production_companies release_date  \
# 1245  [Walt Disney Pictures, Jerry Bruckheimer Films...   2013-07-03
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале

# %%
 answers['11'] = '3. Drama'

# %%
data2.explode('genres').groupby('genres')['imdb_id'].count().sort_values(ascending = False)
# Out:
# genres
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# Name: imdb_id, dtype: int64

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
 answers['12'] = '1. Drama'

# %%
d5 = data2[data2['profit'] > 0]
d5
# Out:
#         imdb_id     budget     revenue                original_title  \
# 0     tt0369610  150000000  1513528810                Jurassic World
# 1     tt1392190  150000000   378436354            Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                     Insurgent
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                     Furious 7
# ...         ...        ...         ...                           ...
# 1871  tt0171433   30000000    37036004             Keeping the Faith
# 1875  tt0219854   65000000    69700000                       The Kid
# 1877  tt0199725   20000000    27728118             Love & Basketball
# 1883  tt0122459   24000000    36609995                  Return to Me
# 1884  tt0120903   75000000   157299717                         X-Men
#
#                                                    cast  \
# 0     [Chris Pratt, Bryce Dallas Howard, Irrfan Khan...
# ...

# %%
d5.explode('genres').groupby('genres')['imdb_id'].count().sort_values(ascending = False)
# Out:
# genres
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# Name: imdb_id, dtype: int64

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
 answers['13'] = '5. Peter Jackson'

# %%
data2.explode('director').groupby('director')['revenue'].sum().sort_values(ascending = False)
# Out:
# director
# Peter Jackson        6490593685
# Christopher Nolan    4167548502
# David Yates          4154295625
# Michael Bay          3886938960
# J.J. Abrams          3579169916
#                         ...
# David MichÃ´d           2295423
# Steven Shainberg        2281089
# Paul Schrader           2062066
# Keanu Reeves            2054941
# Simon Hunter            2033165
# Name: revenue, Length: 997, dtype: int64

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
 answers['14'] = '3. Robert Rodriguez'

# %%
d6 = data.copy()
d6 = d6[d6.genres.str.contains('Action', na=False)]
d6['director'] = d6.director.str.split('|')
d6.explode('director').groupby(['director'])['imdb_id'].count().sort_values(ascending = False)
# Out:
# director
# Robert Rodriguez      9
# Michael Bay           7
# Paul W.S. Anderson    7
# Ridley Scott          6
# Antoine Fuqua         6
#                      ..
# John Whitesell        1
# Brian A Miller        1
# Jon Amiel             1
# Jon Avnet             1
# Luis Mandoki          1
# Name: imdb_id, Length: 364, dtype: int64

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
 answers['15'] = '3. Chris Hemsworth'

# %%
d7 = data.copy()
d7 = d7.loc[d7.release_year == 2012]
d7['cast'] = d7.cast.str.split('|')
d7.explode('cast').groupby('cast')['revenue'].sum().sort_values(ascending = False)
# Out:
# cast
# Chris Hemsworth      2027450773
# Denis Leary          1629460639
# Anne Hathaway        1522851057
# Robert Downey Jr.    1519557910
# Mark Ruffalo         1519557910
#                         ...
# Michael Nyqvist         3428048
# Danny Huston            2106557
# Josh Lucas              2106557
# Sami Gayle              2106557
# Nicolas Cage            2106557
# Name: revenue, Length: 466, dtype: int64

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
 answers['16'] = '3. Matt Damon'

# %%
d8 = data.copy()
d8 = d8[d8.budget > data.budget.mean()]
d8['cast'] = d8.cast.str.split('|')
d8.explode('cast').groupby('cast')["imdb_id"].count().sort_values(ascending = False)
# Out:
# cast
# Matt Damon                 18
# Adam Sandler               17
# Angelina Jolie             16
# Tom Cruise                 15
# Eddie Murphy               15
#                            ..
# Jennifer Hudson             1
# Jennifer Jason Leigh        1
# Jennifer Saunders           1
# Jennifer Tilly              1
# Ã“lafur Darri Ã“lafsson     1
# Name: imdb_id, Length: 1505, dtype: int64

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
 answers['17'] = '2. Action'

# %%
d9 = data.copy()
d9 = d9[d9.cast.str.contains('Nicolas Cage', na=False)]
d9['cast'] = d9.cast.str.split('|')
d9['genres'] = d9.genres.str.split('|')
d9.explode('genres').groupby('genres')['imdb_id'].count().sort_values(ascending = False)
# Out:
# genres
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Animation           3
# Family              3
# Mystery             3
# History             2
# Horror              1
# Romance             1
# War                 1
# Name: imdb_id, dtype: int64

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures?

# %%
 answers['18'] = '1. K-19: The Widowmaker (tt0267626)'

# %%
d10 = data.copy()
d10['profit'] = d10['revenue'] - d10['budget']
d10 = d10[d10.production_companies.str.contains('Paramount Pictures', na=False)]
d10['production_companies'] = d10.production_companies.str.split('|')
d10.loc[d10['profit'] == d10['profit'].min()]
# Out:
#        imdb_id     budget   revenue        original_title  \
# 925  tt0267626  100000000  35168966  K-19: The Widowmaker
#
#                                                   cast         director  \
# 925  Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                       tagline  \
# 925  Fate has found its hero.
#
#                                               overview  runtime  \
# 925  When Russia's first nuclear submarine malfunct...      138
#
#                      genres  \
# 925  Thriller|Drama|History
#
#                                   production_companies release_date  \
# 925  [Paramount Pictures, Intermedia Films, Nationa...    7/19/2002
#
#      vote_average  release_year    profit
# 925           6.0          2002 -64831034

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
 answers['19'] = '5. 2015'

# %%
d11 = data.copy()
d11.groupby('release_year')['revenue'].sum().sort_values(ascending=False)
# Out:
# release_year
# 2015    25449202382
# 2014    23405862953
# 2013    23213799791
# 2012    23079001687
# 2011    22676791872
# 2010    21071204961
# 2009    20261791024
# 2008    18252781990
# 2007    18162406801
# 2004    15663430720
# 2005    15309425558
# 2006    14775042320
# 2003    14346123312
# 2002    14136361487
# 2001    13017764865
# 2000    10664099805
# Name: revenue, dtype: int64

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
 answers['20'] = '1. 2014'

# %%
d12 = data.copy()
d12 = d12[d12.production_companies.str.contains('Warner Bros', na=False)]
d12['production_companies'] = d12.production_companies.str.split('|')
d12['profit'] = d12['revenue'] - d12['budget']
d12.groupby('release_year')['profit'].sum().sort_values(ascending=False)
# Out:
# release_year
# 2014    2295464519
# 2007    2201675217
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1551980298
# 2001    1343545668
# 2012    1258020056
# 2002    1022709901
# 2015     870368348
# 2006     620170743
# 2000     452631386
# Name: profit, dtype: int64

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
 answers['21'] = '4. Сентябрь'

# %%
d13 = data.copy()
d13['release_date'] = pd.to_datetime(d13['release_date'])
d13['month'] = d13.release_date.dt.month
d13
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                             Insurgent
# 3     tt2488496  200000000  2068178225          Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                             Furious 7
# ...         ...        ...         ...                                   ...
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1885  tt0192255   22000000    13555988                    The Little Vampire
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %%
d13.groupby('month')['imdb_id'].count().sort_values(ascending = False)
# Out:
# month
# 9     227
# 12    190
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: imdb_id, dtype: int64

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
 answers['22'] = '2. 450'

# %%
d13.loc[(d13.month > 5) & (d13.month <9)]
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 6     tt1340138  155000000   440603537                    Terminator Genisys
# 8     tt2293640   74000000  1156730962                               Minions
# 9     tt2096673  175000000   853708609                            Inside Out
# 13    tt2120120   88000000   243637091                                Pixels
# ...         ...        ...         ...                                   ...
# 1873  tt0160009   40000000    30199105                        The Art of War
# 1875  tt0219854   65000000    69700000                               The Kid
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
 answers['23'] = '5. Peter Jackson'

# %%
d14 = d13.copy()
d14 = d14.loc[(d14.month == 12) | (d14.month <3)]
d14['director'] = d14.director.str.split('|')
d14.explode('director').groupby('director')['imdb_id'].count().sort_values(ascending = False)
# Out:
# director
# Peter Jackson        7
# Steven Soderbergh    6
# Clint Eastwood       6
# Shawn Levy           4
# Adam Shankman        4
#                     ..
# John Luessenhop      1
# John Musker          1
# John Polson          1
# Callan Brunker       1
# Xavier Palud         1
# Name: imdb_id, Length: 358, dtype: int64

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
 answers['24'] = '5. Four By Two Production'

# %%
d15 = d13.copy()
d15['len_title'] = d15.original_title.apply(lambda x:len(str(x)))
d15['production_companies'] = d15.production_companies.str.split('|')
d15.explode('production_companies').groupby('production_companies')['len_title'].mean().sort_values(ascending=False)
# Out:
# production_companies
# Four By Two Productions       83.0
# Jim Henson Company, The       59.0
# Dos Corazones                 47.0
# Polsky Films                  46.0
# Museum Canada Productions     46.0
#                               ...
# Everest Entertainment          3.0
# Berlanti Productions           3.0
# Global Entertainment Group     2.0
# XM2 Productions                2.0
# Ixtlan Productions             2.0
# Name: len_title, Length: 1771, dtype: float64

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
 answers['25'] = '3. Midnight Picture Show'

# %%
d16 = d13.copy()
d16['len_overview'] = d16.overview.apply(lambda x:len(str(x)))
d16['production_companies'] = d16.production_companies.str.split('|')
d16.explode('production_companies').groupby('production_companies')['len_overview'].mean().sort_values(ascending=False)
# Out:
# production_companies
# Midnight Picture Show                    1000.0
# Room 9 Entertainment                      964.0
# Brookwell-McNamara Entertainment          936.0
# Lions Gate Family Entertainment           909.0
# Crest Animation Productions               909.0
#                                           ...
# London Boulevard                           74.0
# Henceforth                                 74.0
# Phantom Four                               72.0
# Empire Pictures                            62.0
# Motion Picture Corporation of America      59.0
# Name: len_overview, Length: 1771, dtype: float64

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
 answers['26'] = '1. Inside Out, The Dark Knight, 12 Years a Slave'

# %%
d17 = data.copy()
d17.vote_average.quantile(0.99)
# Out:
# 7.8

# %%
d17 = d17[d17['vote_average'] >= 7.8]
d17
# Out:
#         imdb_id     budget     revenue  \
# 9     tt2096673  175000000   853708609
# 28    tt1895587   20000000    88346473
# 34    tt3170832    6000000    35401758
# 118   tt0816692  165000000   621752480
# 119   tt2015381  170000000   773312399
# 124   tt2245084  165000000   652105443
# 125   tt2084970   14000000   233555708
# 128   tt2267998   61000000   369330363
# 138   tt2278388   30000000   174600318
# 155   tt2980516   15000000   121201940
# 177   tt2582846   12000000   305151265
# 283   tt0485947   47000000     3547209
# 316   tt1187043    9000000    70000000
# 370   tt1375666  160000000   825500000
# 496   tt0120737   93000000   871368364
# 599   tt0468569  185000000  1001921825
# 863   tt0167261   79000000   926287400
# 872   tt0253474   35000000   120072577
# 1081  tt0167260   94000000  1118888979
# 1183  tt0993846  100000000   392000694
# 1188  tt1798709   23000000    47351251
# 1191  tt2024544   20000000   187000000
# 1205  tt1392214   46000000   122126687
# ...

# %%
d17.loc[(d17.original_title == '12 years a Slave')|(d17.original_title == 'The Dark Knight')|(d17.original_title == 'Inside Out')]
# Out:
#        imdb_id     budget     revenue   original_title  \
# 9    tt2096673  175000000   853708609       Inside Out
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 9    Amy Poehler|Phyllis Smith|Richard Kind|Bill Ha...        Pete Docter
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#                                       tagline  \
# 9    Meet the little voices inside your head.
# 599                           Why So Serious?
#
#                                               overview  runtime  \
# 9    Growing up can be a bumpy road, and it's no ex...       94
# 599  Batman raises the stakes in his war on crime. ...      152
#
#                           genres  \
# 9        Comedy|Animation|Family
# 599  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# ...

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %%
 answers['27'] = '5. Daniel Radckiffe & Rupert Grint'

# %%
d18 = data.copy()
d18['cast'] = d18.cast.str.split('|')
d18.cast = d18.cast.apply(lambda x: list(it.combinations(sorted(x), 2)))
d18.explode('cast').cast.value_counts()
# Out:
# (Daniel Radcliffe, Emma Watson)        8
# (Daniel Radcliffe, Rupert Grint)       8
# (Emma Watson, Rupert Grint)            8
# (Ben Stiller, Owen Wilson)             6
# (Helena Bonham Carter, Johnny Depp)    6
#                                       ..
# (Hugh Jackman, Rooney Mara)            1
# (Eve Hewson, Kerry Condon)             1
# (Christine Taylor, John Krasinski)     1
# (George Clooney, Shailene Woodley)     1
# (Emjay Anthony, Toni Collette)         1
# Name: cast, Length: 17943, dtype: int64

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': '2. Gods and Generals  (tt0279111)',
#  '3': '3. Winnie the Pooh (tt1449283)',
#  '4': '2. 110',
#  '5': '1. 107',
#  '6': '5. Avatar (tt0499549)',
#  '7': '5. The Lone Ranger  (tt1210819)',
#  '8': '1. 1478 ',
#  '9': '4. The Dark Knight (tt0468569)',
#  '10': '5. The Lone Ranger (tt1210819)',
#  '11': '3. Drama',
#  '12': '1. Drama',
#  '13': '5. Peter Jackson',
#  '14': '3. Robert Rodriguez',
#  '15': '3. Chris Hemsworth',
#  '16': '3. Matt Damon',
#  '17': '2. Action',
#  '18': '1. K-19: The Widowmaker (tt0267626)',
#  '19': '5. 2015',
#  '20': '1. 2014',
#  '21': '4. Сентябрь',
#  '22': '2. 450',
#  '23': '5. Peter Jackson',
#  '24': '5. Four By Two Production',
#  '25': '3. Midnight Picture Show',
#  '26': '1. Inside Out, The Dark Knight, 12 Years a Slave',
#  '27': '5. Daniel Radckiffe & Rupert Grint'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
